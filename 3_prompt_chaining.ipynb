# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_groq import ChatGroq
from dotenv import load_dotenv

# %%
load_dotenv()

model = ChatGroq(model="llama-3.3-70b-versatile")

# %%
#create a state

class BlogState(TypedDict):

    title: str
    outline: str
    content : str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title 
    title = state['title']

    #create outline
    prompt = f'generate a detailed outline for a blog on topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:
    title = state['title']
    outline = state['outline']

    prompt = f'write a detailed blog on topic - {title} using following outine \n {outline}'
    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

graph.add_node('create_outline' , create_outline)
graph.add_node('create_blog' , create_blog)

graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
initial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(initial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': 'Here is a detailed outline for a blog on the topic "Rise of AI in India":\n\n**I. Introduction**\n\n* Brief overview of Artificial Intelligence (AI) and its growing importance globally\n* Importance of AI in the Indian context: economic growth, innovation, and competitiveness\n* Thesis statement: India is rapidly emerging as a major hub for AI, with significant investments, innovations, and applications across various sectors.\n\n**II. Current State of AI in India**\n\n* Overview of the Indian AI ecosystem: startups, research institutions, and industry players\n* Key statistics:\n\t+ Number of AI startups in India\n\t+ Funding received by AI startups in India\n\t+ Growth rate of the Indian AI market\n* Major AI hubs in India: Bengaluru, Delhi-NCR, Mumbai, and Hyderabad\n\n**III. Drivers of AI Growth in India**\n\n* Government initiatives:\n\t+ National AI Strategy (2018)\n\t+ Establishment of the National Institution for Transforming India (NITI Aayog) AI Task Force\n\t+ Funding for AI research and development\n* Private sector investments:\n\t+ Major companies investing in AI research and development in India (e.g., Google, Microsoft, IBM)\n\t+ Indian companies leveraging AI for business growth (e.g., Flipkart, Paytm)\n* Talent pool:\n\t+ Availability of skilled AI professionals in India\n\t+ Initiatives to develop AI talent in India (e.g., AI courses, training programs)\n\n**IV. Applications of AI in India**\n\n* Industry-wise applications:\n\t+ Healthcare: AI in medical diagnosis, patient care, and medical research\n\t+ Finance: AI in banking, insurance, and financial services\n\t+ Retail: AI in customer service, marketing, and supply chain management\n\t+ Education: AI in learning platforms, adaptive assessments, and student support\n* Sector-wise applications:\n\t+ Agriculture: AI in precision farming, crop monitoring, and yield prediction\n\t+ Transportation: AI in traffic management, route optimization, and autonomous vehicles\n\t+ Energy: AI in energy efficiency, grid management, and renewable energy integration\n\n**V. Challenges and Opportunities**\n\n* Challenges:\n\t+ Data quality and availability\n\t+ Regulatory framework and ethics\n\t+ Cybersecurity concerns\n\t+ Job displacement and skills gap\n* Opportunities:\n\t+ Leveraging AI for social good (e.g., healthcare, education, environmental sustainability)\n\t+ Creating new job opportunities in AI and related fields\n\t+ Enhancing business competitiveness and innovation\n\t+ Fostering collaboration between industry, academia, and government\n\n**VI. Future Outlook**\n\n* Predictions for the Indian AI market: growth rate, key trends, and emerging applications\n* India\'s potential to become a global AI leader: strengths, weaknesses, opportunities, and threats\n* Call to action: encouraging stakeholders to invest in AI research, development, and adoption in India\n\n**VII. Conclusion**\n\n* Recap of the rise of AI in India: key drivers, applications, challenges, and opportunities\n* Final thoughts: India\'s AI journey is just beginning, and it is essential to address the challenges and leverage the opportunities to ensure a successful and sustainable AI ecosystem.\n\nThis outline provides a comprehensive structure for a blog on the rise of AI in India, covering the current state, drivers, applications, challenges, opportunities, and future outlook. You can expand or modify the sections as needed to fit your writing style and goals.', 'content': '**The Rise of AI in India: A New Era of Innovation and Growth**\n\n**Introduction**\n\nArtificial Intelligence (AI) has been transforming the world at an unprecedented pace, and its importance is growing exponentially. From virtual assistants to self-driving cars, AI has become an integral part of our daily lives. In the Indian context, AI is expected to play a vital role in driving economic growth, innovation, and competitiveness. With significant investments, innovations, and a ...

# %%
print(final_state['outline'])
print(final_state['content'])
# Out:
# Here is a detailed outline for a blog on the topic "Rise of AI in India":
#
# **I. Introduction**
#
# * Brief overview of Artificial Intelligence (AI) and its growing importance globally
# * Importance of AI in the Indian context: economic growth, innovation, and competitiveness
# * Thesis statement: India is rapidly emerging as a major hub for AI, with significant investments, innovations, and applications across various sectors.
#
# **II. Current State of AI in India**
#
# * Overview of the Indian AI ecosystem: startups, research institutions, and industry players
# * Key statistics:
# 	+ Number of AI startups in India
# 	+ Funding received by AI startups in India
# 	+ Growth rate of the Indian AI market
# * Major AI hubs in India: Bengaluru, Delhi-NCR, Mumbai, and Hyderabad
#
# **III. Drivers of AI Growth in India**
#
# * Government initiatives:
# 	+ National AI Strategy (2018)
# 	+ Establishment of the National Institution for Transforming India (NITI Aayog) AI Task Force
# 	+ Funding for AI research and development
# * Private sector investments:
# 	+ Major companies investing in AI research and development in India (e.g., Google, Microsoft, IBM)
# 	+ Indian companies leveraging AI for business growth (e.g., Flipkart, Paytm)
# * Talent pool:
# 	+ Availability of skilled AI professionals in India
# 	+ Initiatives to develop AI talent in India (e.g., AI courses, training programs)
#
# **IV. Applications of AI in India**
#
# * Industry-wise applications:
# 	+ Healthcare: AI in medical diagnosis, patient care, and medical research
# 	+ Finance: AI in banking, insurance, and financial services
# 	+ Retail: AI in customer service, marketing, and supply chain management
# 	+ Education: AI in learning platforms, adaptive assessments, and student support
# * Sector-wise applications:
# 	+ Agriculture: AI in precision farming, crop monitoring, and yield prediction
# 	+ Transportation: AI in traffic management, route optimization, and autonomous vehicles
# 	+ Energy: AI in energy efficiency, grid management, and renewable energy integration
#
# **V. Challenges and Opportunities**
#
# * Challenges:
# 	+ Data quality and availability
# 	+ Regulatory framework and ethics
# 	+ Cybersecurity concerns
# 	+ Job displacement and skills gap
# * Opportunities:
# 	+ Leveraging AI for social good (e.g., healthcare, education, environmental sustainability)
# 	+ Creating new job opportunities in AI and related fields
# 	+ Enhancing business competitiveness and innovation
# 	+ Fostering collaboration between industry, academia, and government
#
# **VI. Future Outlook**
#
# * Predictions for the Indian AI market: growth rate, key trends, and emerging applications
# * India's potential to become a global AI leader: strengths, weaknesses, opportunities, and threats
# * Call to action: encouraging stakeholders to invest in AI research, development, and adoption in India
#
# **VII. Conclusion**
#
# * Recap of the rise of AI in India: key drivers, applications, challenges, and opportunities
# * Final thoughts: India's AI journey is just beginning, and it is essential to address the challenges and leverage the opportunities to ensure a successful and sustainable AI ecosystem.
#
# This outline provides a comprehensive structure for a blog on the rise of AI in India, covering the current state, drivers, applications, challenges, opportunities, and future outlook. You can expand or modify the sections as needed to fit your writing style and goals.
# **The Rise of AI in India: A New Era of Innovation and Growth**
#
# **Introduction**
#
# Artificial Intelligence (AI) has been transforming the world at an unprecedented pace, and its importance is growing exponentially. From virtual assistants to self-driving cars, AI has become an integral part of our daily lives. In the Indian context, AI is expected to play a vital role in driving economic growth, innovation, and competitiveness. With significant investments, innovations, and applications across various sectors, India is rapidly emerging as a major hub for AI. This blog will explore the current state of AI in India, its drivers, applications, challenges, and opportunities, and provide a future outlook for the Indian AI market.
#
# **Current State of AI in India**
#
# The Indian AI ecosystem is thriving, with a large number of startups, research institutions, and industry players actively involved in AI development and deployment. According to a recent report, there are over 3,000 AI startups in India, with many more in the pipeline. These startups have received significant funding, with investments totaling over $1 billion in the past year alone. The Indian AI market is growing at a rapid pace, with a projected growth rate of 30% per annum. The major AI hubs in India are Bengaluru, Delhi-NCR, Mumbai, and Hyderabad, which have become hotspots for AI innovation and entrepreneurship.
#
# Some key statistics that highlight the current state of AI in India include:
#
# * The number of AI startups in India has increased by 50% in the past two years.
# * The Indian AI market is expected to reach $7.8 billion by 2025.
# * Bengaluru has the highest number of AI startups, followed by Delhi-NCR and Mumbai.
#
# **Drivers of AI Growth in India**
#
# The growth of AI in India can be attributed to several factors, including government initiatives, private sector investments, and a talented pool of professionals.
#
# The Indian government has been actively promoting AI development and adoption through various initiatives, such as the National AI Strategy (2018) and the establishment of the National Institution for Transforming India (NITI Aayog) AI Task Force. The government has also provided funding for AI research and development, which has encouraged innovation and entrepreneurship in the sector.
#
# Private sector companies, both Indian and international, have been investing heavily in AI research and development in India. Companies like Google, Microsoft, and IBM have set up AI research centers in India, while Indian companies like Flipkart and Paytm are leveraging AI to drive business growth.
#
# India has a large and talented pool of professionals, with many Indians working in AI-related fields around the world. To develop AI talent in India, several initiatives have been launched, including AI courses, training programs, and hackathons. These initiatives have helped to create a skilled workforce that is driving AI innovation and adoption in India.
#
# **Applications of AI in India**
#
# AI has a wide range of applications across various sectors in India, including healthcare, finance, retail, education, agriculture, transportation, and energy.
#
# In healthcare, AI is being used for medical diagnosis, patient care, and medical research. For example, AI-powered chatbots are being used to provide medical consultations, while AI algorithms are being used to analyze medical images and diagnose diseases.
#
# In finance, AI is being used for banking, insurance, and financial services. For example, AI-powered virtual assistants are being used to provide customer support, while AI algorithms are being used to detect fraud and predict credit risk.
#
# In retail, AI is being used for customer service, marketing, and supply chain management. For example, AI-powered chatbots are being used to provide customer support, while AI algorithms are being used to personalize marketing messages and optimize supply chains.
#
# In education, AI is being used for learning platforms, adaptive assessments, and student support. For example, AI-powered learning platforms are being used to provide personalized learning experiences, while AI algorithms are being used to assess student performance and provide feedback.
#
# In agriculture, AI is being used for precision farming, crop monitoring, and yield prediction. For example, AI-powered drones are being used to monitor crop health, while AI algorithms are being used to predict crop yields and optimize farming practices.
#
# In transportation, AI is being used for traffic management, route optimization, and autonomous vehicles. For example, AI-powered traffic management systems are being used to optimize traffic flow, while AI algorithms are being used to optimize routes and reduce fuel consumption.
#
# In energy, AI is being used for energy efficiency, grid management, and renewable energy integration. For example, AI-powered energy management systems are being used to optimize energy consumption, while AI algorithms are being used to predict energy demand and optimize grid operations.
#
# **Challenges and Opportunities**
#
# While AI has the potential to transform various sectors in India, there are several challenges that need to be addressed.
#
# One of the major challenges is data quality and availability. AI algorithms require high-quality data to function effectively, but data quality is often a concern in India. To address this challenge, it is essential to develop data collection and storage infrastructure that can provide high-quality data for AI applications.
#
# Another challenge is the regulatory framework and ethics. As AI becomes more pervasive, there is a need to develop a regulatory framework that can address concerns around data privacy, security, and ethics. The Indian government has taken steps to address these concerns, but more needs to be done to create a comprehensive regulatory framework.
#
# Cybersecurity is another major concern, as AI systems can be vulnerable to cyber attacks. To address this challenge, it is essential to develop robust cybersecurity measures that can protect AI systems from cyber threats.
#
# Job displacement and skills gap are also significant concerns, as AI has the potential to automate many jobs. To address this challenge, it is essential to develop training programs that can help workers develop the skills they need to work with AI systems.
#
# Despite these challenges, there are many opportunities for AI in India. AI can be leveraged for social good, such as improving healthcare, education, and environmental sustainability. AI can also create new job opportunities in AI and related fields, and enhance business competitiveness and innovation.
#
# **Future Outlook**
#
# The Indian AI market is expected to grow rapidly in the next few years, with a projected growth rate of 30% per annum. The market is expected to reach $7.8 billion by 2025, driven by increasing adoption of AI across various sectors.
#
# India has the potential to become a global AI leader, with many strengths, including a large and talented pool of professionals, a growing startup ecosystem, and a favorable business environment. However, there are also weaknesses, such as a lack of infrastructure, regulatory challenges, and cybersecurity concerns.
#
# To address these challenges and leverage the opportunities, it is essential to invest in AI research, development, and adoption in India. The government, industry, and academia must work together to create a comprehensive AI ecosystem that can drive innovation and growth.
#
# **Conclusion**
#
# In conclusion, the rise of AI in India is a significant trend that has the potential to transform various sectors and drive economic growth, innovation, and competitiveness. While there are challenges that need to be addressed, there are also many opportunities for AI in India. By investing in AI research, development, and adoption, and by creating a comprehensive AI ecosystem, India can become a global AI leader and drive growth and innovation in the years to come.
#
# The Indian AI journey is just beginning, and it is essential to address the challenges and leverage the opportunities to ensure a successful and sustainable AI ecosystem. As we move forward, it is essential to prioritize AI research, development, and adoption, and to create a favorable business environment that can drive innovation and growth. With the right approach, India can become a global AI hub and drive growth, innovation, and prosperity for all.
